# %% [markdown]
# <a href="https://colab.research.google.com/github/acb100cias/BioMateFC/blob/master/Python1_2027-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
123123*12312.22

# %%
28**9

# %%
28*0.5

# %%
28**9

# %%
import math

# %%
math.pi

# %%
math.sin(0.5)

# %%
math.cos(0.5)

# %%
math.exp(12)

# %%
math.e

# %%
import numpy as np

# %%
L1=[1,2,3,4,5,6,4.4,math.e,math.pi]

# %%
L2=['esta','es' ,'una','lista']

# %%
L1[-1]

# %%
L1.append(12122)

# %%
L1[-1]

# %%
np.array(L1)

# %%
list(range(10))

# %%
np.sin(np.array(range(10)))

# %%
np.arange(-1,1,0.01)

# %%
np.sin(np.arange(-1,1,0.01))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(-np.pi,np.pi,0.01),np.sin(np.arange(-np.pi,np.pi,0.01)))

# %%
def f(x,r):
  return r*x*(1-x)

# %%
r=0.1
f(2,r)

# %%
X=np.arange(0,1,0.01)
plt.plot(X,f(X,r))

# %% [markdown]
# $$x(0)=x_0 $$
# $$ x(t)=x_{t-1}+f

# %%
X=[0.1]
for i in range(100):
  X.append(X[-1]+f(X[-1],1.5))

# %%
X

# %%
plt.plot(X)

# %%
X=np.arange(0,1,0.01)
plt.plot(X,f(X,0.5))
plt.plot(X,f(X,1))
plt.plot(X,f(X,1.1))
plt.plot(X,f(X,1.5))
plt.plot(X,f(X,1.8))
plt.plot(X,f(X,2))
plt.plot(X,X)

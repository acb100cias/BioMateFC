# %%
ls
# Out:
# abm-ants-pheromone.py
# abm-ants.py
# abm-DLA.py
# abm-keller-segel.py
# abm-predator-prey-evolvable.py
# abm-predatorprey-old.py
# abm-predatorprey-old-withplot.py
# abm-predator-prey.py
# abm-predator-prey-with-plot.py
# abm-randomwalk.py
# abm-segregation-continuous.py
# abm-segregation-discrete.py
# abm-swarm.py
# ca-cobweb-plot-for-mfa.py
# ca-cobweb-plot-for-rga.py
# ca-excitablemedia.py
# ca-forestfire.py
# ca-gameoflife.py
# ca-graph-based-phasespace-pie.py
# ca-graph-based-phasespace.py
# ca-hostpathogen.py
# ca-majority.py
# ca-panic.py
# ca-turing.py
# ds-bifurcation-diagram-hysteresis.py
# ds-bifurcationdiagram-numerical-logistic-map.py
# ds-bifurcation-diagram-numerical.py
# ds-bifurcation-diagram-pitchfork-subcritical.py
# ds-bifurcation-diagram-pitchfork-supercritical.py
# ds-bifurcation-diagram-saddlenode.py
# ds-bifurcation-diagram-transcritical.py
# ds-chaotic-behavior-butterfly-effect.py
# ds-chaotic-behavior-logistic-map.py
# ds-chaotic-behavior.py
# ds-cobweb-plot-exercise.py
# ds-cobweb-plot.py
# ds-exponential-growth.py
# ds-exponential-growth-time.py
# ds-graph-based-phasespace-exercise.py
# ds-graph-based-phasespace.py
# ds-logisticgrowth-continuous.py
# ds-Lorenz-equations.py
# ds-Lyapunov-exponent.py
# ds-oscillation-correct-phasespace.py
# ds-oscillation-correct.py
# ds-oscillation-wrong.py
# ds-period-doubling-bifurcation-cobweb.py
# ds-period-doubling-bifurcation.py
# ds-phasespace-drawing-3D.py
# ds-phasespace-drawing-bad.py
# ds-phasespace-drawing-exercise.py
# ds-phasespace-drawing-fibonacci.py
# ds-phasespace-drawing.py
# ds-phasespace-drawing-streamplot.py
# ds-predator-prey-continuous.py
# ds-predator-prey.py
# ds-van-del-pol-Hopf-bifurcation.py
# dynamic-randomwalk-pSetter.py
# dynamic-randomwalk.py
# dynamic-randomwalk-standalone.py
# interactive-template.py
# LICENSE
# net-attack.py
# net-barabasi-albert.py
# net-cascade-of-failure.py
# net-ccdfs-loglog.py
# net-communities.py
# net-degree-correlation.py
# net-degree-distributions-loglog.py
# net-diffusion-adaptive.py
# net-diffusion.py
# net-drawing-options.py
# net-exponent-estimation.py
# net-hopfield.py
# net-karate-club-visualization.py
# net-kuramoto-desync.py
# net-kuramoto.py
# net-kuramoto-with-phase.py
# net-layouts.py
# net-LDR.py
# net-majority.py
# net-networkgrowth-old.py
# net-networkx-demo1.py
# net-networkx-demo2.py
# net-networkx-test1.py
# net-networkx-test2.py
# net-percolation-plot.py
# net-percolation.py
# net-random-graphs.py
# net-read-adjlist-directed.py
# net-read-adjlist.py
# net-shortest-path.py
# net-SIS-adaptive.py
# net-SIS-large-graph-adaptive.py
# net-SIS-large-graph-parametersweep.py
# net-SIS-large-graph.py
# net-SIS.py
# net-SIS-synchronous-update.py
# net-small-world-exercise.py
# net-small-world-experiment.py
# net-small-world.py
# net-sync-analysis.py
# net-voter.py
# pde-BZ-reaction.py
# pde-plot-contour.py
# pde-plot-imshow.py
# pde-plot-surface-3D.py
# pde-plot-vector-field.py
# pde-population-economy.py
# pde-transport-error.py
# pde-transport-escaping.py
# pde-transport-imshow.py
# pde-transport.py
# pde-turing.py
# __pycache__/
# pycxsimulator.py
# pycxsimulator.pyc
# README.md
# Untitled.ipynb

# %%
# %load net-SIS-adaptive.py
import pycxsimulator
from pylab import *

import networkx as nx

def initialize():
    global g
    g = nx.karate_club_graph()
    g.pos = nx.spring_layout(g)
    for i in g.nodes:
        g.nodes[i]['state'] = 1 if random() < .5 else 0
    
def observe():
    global g
    cla()
    nx.draw(g, cmap = cm.Wistia, vmin = 0, vmax = 1,
            node_color = [g.nodes[i]['state'] for i in g.nodes],
            pos = g.pos)

p_i = 0.5 # infection probability
p_r = 0.1 # recovery probability
p_s = 0.5 # severance probability

def update():
    global g
    a = choice(list(g.nodes))
    if g.nodes[a]['state'] == 0: # if susceptible
        if g.degree(a) > 0:
            b = choice(list(g.neighbors(a)))
            if g.nodes[b]['state'] == 1: # if neighbor b is infected
                if random() < p_s:
                    g.remove_edge(a, b)
                else:
                    g.nodes[a]['state'] = 1 if random() < p_i else 0
    else: # if infected
        g.nodes[a]['state'] = 0 if random() < p_r else 1

pycxsimulator.GUI().start(func=[initialize, observe, update])
